# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
sb.set()

# %%
mobile = pd.read_csv("mobile_price_data.csv")

# %%
mobile.head()
# Out:
#                             mobile_name mobile_price mobile_color  dual_sim  \
# 0    Realme Narzo 10A (So White, 32 GB)       ₹8,999     So White  Dual Sim
# 1     Realme Narzo 10A (So Blue, 32 GB)       ₹8,999      So Blue  Dual Sim
# 2     Realme Narzo 10A (So Blue, 64 GB)       ₹9,999      So Blue  Dual Sim
# 3    Realme Narzo 10A (So White, 64 GB)       ₹9,999     So White  Dual Sim
# 4  Realme Narzo 10 (That Green, 128 GB)      ₹11,999   That Green  Dual Sim
#
#               disp_size         resolution          os  num_cores mp_speed  \
# 0  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 1  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 2  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 3  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 4   16.51 cm (6.5 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
#
#   int_memory   ram                   p_cam              f_cam  \
# 0      32 GB  3 GB        12MP + 2MP + 2MP   5MP Front Camera
# 1      32 GB  3 GB        12MP + 2MP + 2MP   5MP Front Camera
# 2      64 GB  4 GB        12MP + 2MP + 2MP   5MP Front Camera
# 3      64 GB  4 GB        12MP + 2MP + 2MP   5MP Front Camera
# 4     128 GB  4 GB  48MP + 8MP + 2MP + 2MP  16MP Front Camera
#
#                 network bluetooth battery_power mob_width mob_height  \
# 0  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 1  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 2  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 3  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh     75 mm   164.4 mm
# 4  4G VOLTE, 4G, 3G, 2G       Yes      5000 mAh   75.4 mm   164.4 mm
#
#   mob_depth mob_weight
# 0   8.95 mm      195 g
# 1   8.95 mm      195 g
# 2   8.95 mm      195 g
# 3   8.95 mm      195 g
# 4      9 mm      199 g

# %%
import re
mobile["disp_size"] = mobile["disp_size"].apply(lambda x: re.sub(r'(.+)(cm)(.+)',r'\1', x))
mobile["mp_speed"] = mobile["mp_speed"].apply(lambda x: re.sub(r'(.+)( GHz)',r'\1', x))
mobile["int_memory"] = mobile["int_memory"].apply(lambda x: re.sub(r'(.+)( GB)',r'\1', x))
mobile["ram"] = mobile["ram"].apply(lambda x: re.sub(r'(.+)( GB)',r'\1', x))
mobile["battery_power"] = mobile["battery_power"].apply(lambda x: re.sub(r'(.+)( mAh)',r'\1', x))
mobile["mob_width"] = mobile["mob_width"].apply(lambda x: re.sub(r'(.+)( mm)',r'\1', x))
mobile["mob_height"] = mobile["mob_height"].apply(lambda x: re.sub(r'(.+)( mm)',r'\1', x))
mobile["mob_depth"] = mobile["mob_depth"].apply(lambda x: re.sub(r'(.+)( mm)',r'\1', x))
mobile["mob_weight"] = mobile["mob_weight"].apply(lambda x: re.sub(r'(.+)( g)',r'\1', x)) 
mobile[['mobile_brand', 'model_name']] = mobile['mobile_name'].str.split(' ', 1, expand=True)
mobile.drop('mobile_name', inplace=True, axis=1)

mobile["model_name"] = mobile["model_name"].apply(lambda x: re.sub(r'(.*?) \((.*)',r'\1', x))

mobile[['resolution_width', 'resolution_height']] = mobile['resolution'].str.split(r'x|×|\*', 1, expand=True)
mobile.drop('resolution', inplace=True, axis=1)
mobile["resolution_height"] = mobile["resolution_height"].astype(str)
mobile["resolution_height"] = mobile["resolution_height"].apply(lambda x: re.sub(r'(\d+)(.*)',r'\1', x))

mobile[['f_cam_1', 'f_cam_2']] = mobile['f_cam'].str.split('+', 1, expand=True)
mobile.drop('f_cam', inplace=True, axis=1)
mobile["f_cam_1"] = mobile["f_cam_1"].astype(str)
mobile["f_cam_2"] = mobile["f_cam_2"].astype(str)
mobile["f_cam_1"] = mobile["f_cam_1"].apply(lambda x: re.sub(r'(\D+)(\d+)(\D+)',r'\2', x))
mobile["f_cam_1"] = mobile["f_cam_1"].apply(lambda x: re.sub(r'(\d+)(\D+)',r'\1', x))
mobile["f_cam_1"] = mobile["f_cam_1"].apply(lambda x: re.sub(r'(\D+)',r'', x))
mobile["f_cam_2"] = mobile["f_cam_2"].apply(lambda x: re.sub(r'(\D+)(\d+)(\D+)',r'\2', x))
mobile["f_cam_2"] = mobile["f_cam_2"].apply(lambda x: re.sub(r'(\d+)(\D+)',r'\1', x))
mobile["f_cam_2"] = mobile["f_cam_2"].apply(lambda x: re.sub(r'(\D+)',r'', x))

mobile[['p_cam_1', 'p_cam_2', 'p_cam_3', 'p_cam_4']] = mobile['p_cam'].str.split('+', 4, expand=True)
mobile.drop('p_cam', inplace=True, axis=1)
mobile["p_cam_1"] = mobile["p_cam_1"].astype(str)
mobile["p_cam_2"] = mobile["p_cam_2"].astype(str)
mobile["p_cam_3"] = mobile["p_cam_3"].astype(str)
mobile["p_cam_4"] = mobile["p_cam_4"].astype(str)
mobile["p_cam_1"] = mobile["p_cam_1"].apply(lambda x: re.sub(r'(\D+)(\d+)(\D+)',r'\2', x))
mobile["p_cam_1"] = mobile["p_cam_1"].apply(lambda x: re.sub(r'(\d+)(\D+)',r'\1', x))
mobile["p_cam_1"] = mobile["p_cam_1"].apply(lambda x: re.sub(r'(\D+)',r'', x))
mobile["p_cam_2"] = mobile["p_cam_2"].apply(lambda x: re.sub(r'(\D+)(\d+)(\D+)',r'\2', x))
mobile["p_cam_2"] = mobile["p_cam_2"].apply(lambda x: re.sub(r'(\d+)(\D+)',r'\1', x))
mobile["p_cam_2"] = mobile["p_cam_2"].apply(lambda x: re.sub(r'(\D+)',r'', x))
mobile["p_cam_3"] = mobile["p_cam_3"].apply(lambda x: re.sub(r'(\D+)(\d+)(\D+)',r'\2', x))
mobile["p_cam_3"] = mobile["p_cam_3"].apply(lambda x: re.sub(r'(\d+)(\D+)',r'\1', x))
mobile["p_cam_3"] = mobile["p_cam_3"].apply(lambda x: re.sub(r'(\D+)',r'', x))
mobile["p_cam_4"] = mobile["p_cam_4"].apply(lambda x: re.sub(r'(\D+)(\d+)(\D+)',r'\2', x))
mobile["p_cam_4"] = mobile["p_cam_4"].apply(lambda x: re.sub(r'(\d+)(\D+)',r'\1', x))
mobile["p_cam_4"] = mobile["p_cam_4"].apply(lambda x: re.sub(r'(\D+)',r'', x))

list1 = [] 
for x in mobile["network"]:
    if "5G" in x:
        list1.append("5G")
    elif "4G VOLTE" in x:
        list1.append("4G VOLTE")
    elif "4G" in x:
        list1.append("4G")
    elif "3G" in x:
        list1.append("3G")
    elif "2G" in x:
        list1.append("2G")
mobile["network"] = list1

# %%
mobile.head()
# Out:
#   mobile_price mobile_color  dual_sim disp_size          os  num_cores  \
# 0       ₹8,999     So White  Dual Sim    16.56   Android 10  Octa Core
# 1       ₹8,999      So Blue  Dual Sim    16.56   Android 10  Octa Core
# 2       ₹9,999      So Blue  Dual Sim    16.56   Android 10  Octa Core
# 3       ₹9,999     So White  Dual Sim    16.56   Android 10  Octa Core
# 4      ₹11,999   That Green  Dual Sim    16.51   Android 10  Octa Core
#
#   mp_speed int_memory ram   network  ... mobile_brand model_name  \
# 0        2         32   3  4G VOLTE  ...       Realme  Narzo 10A
# 1        2         32   3  4G VOLTE  ...       Realme  Narzo 10A
# 2        2         64   4  4G VOLTE  ...       Realme  Narzo 10A
# 3        2         64   4  4G VOLTE  ...       Realme  Narzo 10A
# 4        2        128   4  4G VOLTE  ...       Realme   Narzo 10
#
#   resolution_width resolution_height f_cam_1 f_cam_2 p_cam_1 p_cam_2 p_cam_3  \
# 0            1600                720       5              12       2       2
# 1            1600                720       5              12       2       2
# 2            1600                720       5              12       2       2
# 3            1600                720       5              12       2       2
# 4            1600                720      16              48       8       2
#
#   p_cam_4
# 0
# 1
# 2
# 3
# 4       2
#
# [5 rows x 26 columns]

# %%
mobile.sample(10)
# Out:
#     mobile_price     mobile_color  dual_sim disp_size                    os  \
# 443      ₹14,495              Red  Dual Sim    15.75       Android Oreo 8.1
# 150      ₹12,999            Black  Dual Sim    15.21   Android Nougat 7.1.2
# 282      ₹17,990    Nebula Purple  Dual Sim     16.0       Android Oreo 8.1
# 430      ₹13,990  Fluorite Purple  Dual Sim    16.59        Android Pie 9.0
# 76        ₹8,499      Diamond Red  Dual Sim     15.8          Android Pie 9
# 268      ₹11,990       Ocean Blue  Dual Sim     15.8       Android Oreo 8.1
# 380       ₹8,990             Blue  Dual Sim    15.75       Android Oreo 8.1
# 244      ₹15,990   Energetic Blue  Dual Sim    14.48     Android Nougat 7.1
# 265      ₹11,990             Gold  Dual Sim     15.8       Android Oreo 8.1
# 217      ₹27,990      Piano Black  Dual Sim    16.36             Android 10
#
#      num_cores mp_speed int_memory ram   network  ... mobile_brand  \
# 443  Octa Core      1.8         64   4        4G  ...         OPPO
# 150  Octa Core      1.8         64   4  4G VOLTE  ...        Redmi
# 282  Octa Core     1.95         64   4  4G VOLTE  ...         Vivo
# 430  Octa Core      2.1        128   4  4G VOLTE  ...         OPPO
# 76   Octa Core      2.1         32   3  4G VOLTE  ...       Realme
# 268  Octa Core        2         32   2  4G VOLTE  ...         Vivo
# 380  Octa Core      2.3         32   2  4G VOLTE  ...         OPPO
# 244  Octa Core      1.8         32   4  4G VOLTE  ...         Vivo
# 265  Quad Core        2         16   2  4G VOLTE  ...         Vivo
# 217  Octa Core      2.3        128   8  4G VOLTE  ...         Vivo
#
#      model_name resolution_width resolution_height f_cam_1 f_cam_2 p_cam_1  \
# 443         A3s            1520                720       8              13
# 150  Note 5 Pro            2160               1080      20              12
# 282      V9 Pro            2280               1080      16              13
# 430         F11            1080               2340      16              48
# 76            3            1520                720      13              13
# 268         Y91            1520                720       8              13
# 380         A5s            1520                720       8              13
# 244          V7            1440                720      24              16
# 265        Y81i            1520                720       5              13
# 217         V19            2400               1080      32       8      48
#
#     p_cam_2 p_cam_3 p_cam_4
# 443       2
# 150       5
# 282       2
# 430       5
# 76        2
# 268       2
# 380       2
# 244
# 265
# 217       8       2       2
#
# [10 rows x 26 columns]

# %%
mobile["mobile_price"] = mobile["mobile_price"].apply(lambda x: re.sub(r'(.*)\,(.*)',r'\1\2', x))
mobile["mobile_price"] = mobile["mobile_price"].apply(lambda x: re.sub(r'.(\d+)',r'\1', x))
mobile["mobile_price"] = pd.to_numeric(mobile["mobile_price"])
mobile["mobile_price"] = mobile["mobile_price"].apply(lambda x: round(x*0.0178), x)

# %%
mobile.sample(10)
# Out:
#      mobile_price        mobile_color  dual_sim disp_size                os  \
# 391           534           Sky White  Dual Sim    16.26         Android 10
# 138           303  Interstellar Black  Dual Sim    16.94     Android Pie 10
# 294           329               Black  Dual Sim    16.51         Android 10
# 115           303         Aurora Blue  Dual Sim    16.94     Android Pie 10
# 208           320           Iris Blue  Dual Sim    16.59         Android 10
# 237           249               Black  Dual Sim    15.49   Android Oreo 8.1
# 295           311               White  Dual Sim    16.51         Android 10
# 458           249     Fluorite Purple  Dual Sim    16.59    Android Pie 9.0
# 73            169         Diamond Red  Dual Sim     15.8      Android Pie 9
# 56            356         Pearl Green  Dual Sim    16.26      Android Pie 9
#
#      num_cores mp_speed int_memory ram   network  ... mobile_brand  \
# 391  Octa Core      2.2        128   8  4G VOLTE  ...         OPPO
# 138  Octa Core      2.3        128   6  4G VOLTE  ...        Redmi
# 294  Octa Core        2         64   6        4G  ...      Samsung
# 115  Octa Core      2.3         64   4  4G VOLTE  ...        Redmi
# 208  Octa Core        2        128   8  4G VOLTE  ...         Vivo
# 237  Octa Core        2         32   3  4G VOLTE  ...         Vivo
# 295  Octa Core        2         64   4        4G  ...      Samsung
# 458  Octa Core      2.1        128   4  4G VOLTE  ...         OPPO
# 73   Octa Core      2.1         64   4  4G VOLTE  ...       Realme
# 56   Octa Core      2.2        128   6  4G VOLTE  ...       Realme
#
#          model_name resolution_width resolution_height f_cam_1 f_cam_2  \
# 391       Reno3 Pro            2400               1080      44       2
# 138  Note 9 Pro Max            2400               1080      32
# 294     Galaxy A21s            1600                720      13
# 115      Note 9 Pro            2400               1080      16
# 208             Y50            2340               1080      16
# 237             Y81            1520                720       5
# 295     Galaxy A21s            1600                720      13
# 458             F11            1080               2340      16
# 73                3            1520                720      13
# 56               X2            1080               2340      32
#
#     p_cam_1 p_cam_2 p_cam_3 p_cam_4
# 391      64      13       8       2
# 138      64       8       5       2
# 294      48       8       2       2
# 115      48       8       5       2
# 208      13       8       2       2
# 237      13
# 295      48       8       2       2
# 458      48       5
# 73       13       2
# 56       64       8       2       2
#
# [10 rows x 26 columns]

# %%
mobile.sample(10)
# Out:
#      mobile_price   mobile_color  dual_sim disp_size                os  \
# 278           231  Electric Blue  Dual Sim    16.13      Android Pie 9
# 395           267  Thunder Black  Dual Sim    16.51    Android Pie 9.0
# 217           498    Piano Black  Dual Sim    16.36         Android 10
# 384           302   Stream White  Dual Sim    16.51         Android 10
# 304           214          Black  Dual Sim    13.97   Android Nougat 7
# 351           329  Atlantis Blue  Dual Sim    16.94         Android 10
# 406           338    Piano Black  Dual Sim    16.28   Android Oreo 8.1
# 63            116   Diamond Blue  Dual Sim    15.49    Android Pie 9.0
# 72            151  Dynamic Black  Dual Sim     15.8    Android Pie 9.0
# 207           320    Pearl White  Dual Sim    16.59         Android 10
#
#      num_cores mp_speed int_memory ram   network  ... mobile_brand  \
# 278  Octa Core        2         64   4  4G VOLTE  ...         Vivo
# 395  Octa Core      2.1         64   6  4G VOLTE  ...         OPPO
# 217  Octa Core      2.3        128   8  4G VOLTE  ...         Vivo
# 384  Octa Core        2        128   6  4G VOLTE  ...         OPPO
# 304  Octa Core      1.6         16   2        4G  ...      Samsung
# 351  Octa Core      2.2        128   6  4G VOLTE  ...         POCO
# 406  Octa Core     1.95         64   6  4G VOLTE  ...         OPPO
# 63   Octa Core        2         16   2  4G VOLTE  ...       Realme
# 72   Octa Core      2.1         32   3  4G VOLTE  ...       Realme
# 207  Octa Core        2        128   8  4G VOLTE  ...         Vivo
#
#         model_name resolution_width resolution_height f_cam_1 f_cam_2 p_cam_1  \
# 278            U10             720               1544       8              13
# 395        F11 Pro            2340               1080      16              48
# 217            V19            2400               1080      32       8      48
# 384            A52            2400               1080      16              12
# 304  Galaxy J7 Nxt            1280                720       5              13
# 351             X2            2400               1080      20       2      64
# 406             K1            2340               1080      25              16
# 63              C2            1560                720       5              13
# 72               3            1520                720      13              13
# 207            Y50            2340               1080      16              13
#
#     p_cam_2 p_cam_3 p_cam_4
# 278       8       2
# 395       5
# 217       8       2       2
# 384       8       2       2
# 304
# 351       8       2       2
# 406       2
# 63        2
# 72        2
# 207       8       2       2
#
# [10 rows x 26 columns]

# %%
mobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mobile_price       459 non-null    int64
#  1   mobile_color       459 non-null    object
#  2   dual_sim           459 non-null    object
#  3   disp_size          459 non-null    object
#  4   os                 459 non-null    object
#  5   num_cores          459 non-null    object
#  6   mp_speed           459 non-null    object
#  7   int_memory         459 non-null    object
#  8   ram                459 non-null    object
#  9   network            459 non-null    object
#  10  bluetooth          459 non-null    object
#  11  battery_power      459 non-null    object
#  12  mob_width          459 non-null    object
#  13  mob_height         459 non-null    object
#  14  mob_depth          459 non-null    object
#  15  mob_weight         459 non-null    object
#  16  mobile_brand       459 non-null    object
#  17  model_name         459 non-null    object
#  18  resolution_width   459 non-null    object
#  19  resolution_height  459 non-null    object
#  20  f_cam_1            459 non-null    object
#  21  f_cam_2            459 non-null    object
#  22  p_cam_1            459 non-null    object
#  23  p_cam_2            459 non-null    object
#  24  p_cam_3            459 non-null    object
#  25  p_cam_4            459 non-null    object
# dtypes: int64(1), object(25)
# memory usage: 93.4+ KB

# %%
list(mobile.columns.values)
# Out:
# ['mobile_price',
#  'mobile_color',
#  'dual_sim',
#  'disp_size',
#  'os',
#  'num_cores',
#  'mp_speed',
#  'int_memory',
#  'ram',
#  'network',
#  'bluetooth',
#  'battery_power',
#  'mob_width',
#  'mob_height',
#  'mob_depth',
#  'mob_weight',
#  'mobile_brand',
#  'model_name',
#  'resolution_width',
#  'resolution_height',
#  'f_cam_1',
#  'f_cam_2',
#  'p_cam_1',
#  'p_cam_2',
#  'p_cam_3',
#  'p_cam_4']

# %%
mobile = mobile[[
 'mobile_brand',
 'model_name','mobile_price',
 'mobile_color',
 'dual_sim',
 'disp_size',
 'os',
 'num_cores',
 'mp_speed',
 'int_memory',
 'ram',
 'network',
 'bluetooth',
 'battery_power',
 'mob_width',
 'mob_height',
 'mob_depth',
 'mob_weight',
 'resolution_width',
 'resolution_height',
 'f_cam_1',
 'f_cam_2',
 'p_cam_1',
 'p_cam_2',
 'p_cam_3',
 'p_cam_4']]

# %%
mobile.to_csv("mobile_data_new.csv",mode='w+' )
